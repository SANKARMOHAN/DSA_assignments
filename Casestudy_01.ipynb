# %% [markdown]
# <a href="https://colab.research.google.com/github/SANKARMOHAN/DSA_assignments/blob/main/Casestudy_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Case Study #**01**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1) Read the dataset to the python environment.

# %%
data1 = pd.read_csv('cars_data.csv')
data1
# Out:
#          Make        Model    Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 0      Suzuki       Vitara  Philippine  ...              0.13     200.9       11.5
# 1       Honda        S2000      Henrik  ...              0.02     158.5        8.8
# 2         BMW           Z4      Lebbie  ...              0.24     149.5       14.4
# 3      Toyota       Tacoma    Jefferey  ...              0.20     153.3       11.5
# 4        Ford      Festiva     Glendon  ...              0.18     122.0       14.9
# ...       ...          ...         ...  ...               ...       ...        ...
# 9995    Mazda      Tribute      Cooper  ...              0.14     245.8        8.0
# 9996      GMC  Sierra 2500         Dud  ...              0.11     147.4       12.3
# 9997  Mercury      Mariner     Chariot  ...              0.12     198.1       11.8
# 9998   Daewoo      Leganza       Dynah  ...              0.04     206.7       12.2
# ...

# %% [markdown]
# A dataset having 10000 rows and 20 columns are stored.

# %% [markdown]
# # 2) Check for the null values present in the dataset.

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               10000 non-null  object
#  1   Model              10000 non-null  object
#  2   Nickname           10000 non-null  object
#  3   Car Gender         10000 non-null  object
#  4   Buyer Gender       10000 non-null  object
#  5   Buyer Age          10000 non-null  int64
#  6   Buzzword           10000 non-null  object
#  7   Country            10000 non-null  object
#  8   City               10000 non-null  object
#  9   Dealer Latitude    10000 non-null  float64
#  10  Dealer Longitude   10000 non-null  float64
#  11  Color              10000 non-null  object
#  12  New Car            10000 non-null  bool
#  13  Purchase Date      10000 non-null  object
#  14  Sale Price         10000 non-null  float64
#  15  Discount           10000 non-null  float64
# ...

# %% [markdown]
# No null values are present in the dataset

# %% [markdown]
# # 3) Plot a bar graph of male vs female buyers participated in the sales.

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Buyer Gender',data=data1,palette=["#FF6F91", "#2C73D2"])
plt.title('Female vs male',fontsize=25,fontweight='bold')
plt.grid(True)

# %% [markdown]
# From the graph, the total no. of female participants are more than that of male participants.

# %% [markdown]
# # 4) Find the top 5 cars based on their sales price.

# %%
data1.sort_values('Sale Price',axis=0,ascending=False).head()
# Out:
#             Make      Model   Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 5984  Volkswagen  Jetta III    Rachael  ...              0.06     204.9       12.6
# 1270        Audi         A6      Thorn  ...              0.16     171.3       13.0
# 3460       Lexus         LX      Aldin  ...              0.12     193.7        4.5
# 9032       Mazda       MX-6  Sylvester  ...              0.15     232.0        3.9
# 302        Lexus         ES       Brig  ...              0.21     228.1        4.7
#
# [5 rows x 20 columns]

# %% [markdown]
# The top 5 cars are Volkswagen Jetta III, Audi A6, Lexus LX, Mazda MX-6 and Lexus ES.

# %% [markdown]
# # 5)Find the least 5 cars based on their Resell price.

# %%
rsp = data1.sort_values('Resell Price',axis=0,ascending=True).head()
rsp
# Out:
#             Make        Model Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 2446   Chevrolet         1500  Corenda  ...              0.25     239.6       11.2
# 4933         GMC  Savana 1500     Lark  ...              0.01     158.7        9.0
# 566       Jaguar           XF   Payton  ...              0.19     249.3        6.9
# 2538  Mitsubishi       3000GT     Thia  ...              0.14     222.0       10.3
# 5869    Infiniti          G37    Sonny  ...              0.04     131.6       12.3
#
# [5 rows x 20 columns]
